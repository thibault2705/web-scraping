# %%
pip install datascience
# Out:
# Collecting datascience
#   Downloading datascience-0.18.0-py3-none-any.whl.metadata (910 bytes)
# Requirement already satisfied: folium>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from datascience) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from datascience) (75.2.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from datascience) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datascience) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from datascience) (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from datascience) (2.0.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from datascience) (7.34.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from datascience) (5.24.1)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from datascience) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium>=0.9.1->datascience) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium>=0.9.1->datascience) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium>=0.9.1->datascience) (2025.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->datascience) (2.9.0.post0)
# Collecting jedi>=0.16 (from ipython->datascience)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->datascience) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datascience) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datascience) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->datascience) (8.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->datascience) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->datascience) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->datascience) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium>=0.9.1->datascience) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium>=0.9.1->datascience) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium>=0.9.1->datascience) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium>=0.9.1->datascience) (2025.8.3)
# Downloading datascience-0.18.0-py3-none-any.whl (725 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 19.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.3 MB/s eta 0:00:00
# Installing collected packages: jedi, datascience
# Successfully installed datascience-0.18.0 jedi-0.19.2

# %%
# As usual ...
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
CENTRE_LIST_BASE_URL = 'https://www.toronto.ca/data/children/dmc/a2z/a2z{}.html'

# build centre list url
def build_centre_list_url(alphabet):
  return CENTRE_LIST_BASE_URL.format(alphabet)

# %%
CENTRE_DETAIL_BASE_URL = 'https://www.toronto.ca/data/children/dmc/{}'

# build centre detail url
def build_centre_detail_url(relative_link):
  # remove first 3 characters './/'
  relative_link = relative_link[3:]
  return CENTRE_DETAIL_BASE_URL.format(relative_link)

# %%
# define some requests constants
ENCODING = 'utf-8'
FEATURES = 'html.parser'
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# %%
import requests
from bs4 import BeautifulSoup

# get requests and return soup
def get_requests(url):
  response = requests.get(url, headers=HEADERS)

  # set encoding to get rid of, for example, Ysraël becomes Ysra√´l
  response.encoding = ENCODING

  soup = BeautifulSoup(response.text, FEATURES)
  return soup

# %%
def scrape_central_name_and_link(row):
  first_cell = row.find('td')

  # fast fail: No cell found
  if not first_cell:
      return {}

  # otherwise, find link tag
  link_tag = first_cell.find_all('a', href=True)[0]

  # fast fail: no link tag
  if not link_tag:
      return {}

  # otherwise, continue to scrape
  name = link_tag.text
  link = link_tag['href']

  return {
      'name': name,
      'link': build_centre_detail_url(link) # store link for easier access later
  }

# %%
def scrape_all_centres_name_and_link(alphabet):
  # build url first
  url = build_centre_list_url(alphabet)

  soup = get_requests(url)

  table = soup.find('table')

  if not table:
    print(f'\tNo table found. Skip this URL: {url}')
    # return empty array
    return []

  centres = []
  rows = table.find_all('tr')

  for index, row in enumerate(rows):
    child_care = scrape_central_name_and_link(row)

    if child_care:
      centres.append(child_care)

  return centres

# %%
import re # regular expression

def clean_text(original_text):
  # Step 1: Remove all non-printable characters.
  new_text = ''.join(char for char in original_text if char.isprintable())
  # Step 2: Replace any sequence of whitespace with a single space
  new_text = re.sub(r'\s+', ' ', new_text)
  # Step 3: Add space after ','
  new_text = re.sub(r'(,)(\S)', r'\1 \2', new_text)
  # Step 4: Add space before '('
  new_text = re.sub(r'(\S)(\()', r'\1 \2', new_text)
  # Step 5: Remove space before '/'
  new_text = re.sub(r'\s+/', '/', new_text)
  # Step 6: Remove space after '/'
  new_text = re.sub(r'/\s+', '/', new_text)

  return new_text.strip()

# %%
WARD = 'Ward:'
CROSS_STREET_REF_BEGIN = '('

def extract_address(centre, original_text):
  temp_string = clean_text(original_text)

  # ward
  ward_index = temp_string.find(WARD)
  if ward_index != 1:
    ward = temp_string[ward_index + len(WARD):].strip()
    print(f'\tWard:\t{ward}')
    centre['ward'] = ward

    temp_string = temp_string[:ward_index].strip()

  # cross_street_reference
  cross_street_ref_begin_index = temp_string.find(CROSS_STREET_REF_BEGIN)
  if cross_street_ref_begin_index != -1:
    cross_street_ref = clean_text(temp_string[cross_street_ref_begin_index:]
                                  .replace("(", '')
                                  .replace(')', '')
                                  .replace('&', '/'))
    print(f'\tCross Street Reference:\t{cross_street_ref}')
    centre['cross_street_reference'] = cross_street_ref

    temp_string = temp_string[:cross_street_ref_begin_index].strip()

  # address
  address = temp_string

  centre['address'] = address

# %%
PHONE = 'Phone:'
PHONE_EXTENSION = 'ext'
OR_EMAIL = 'or email:'

def extract_contact(centre, original_text):
  phone_index = original_text.find(PHONE)
  email_index = original_text.find(OR_EMAIL)

  contact_name = phone = phone_extension = email = ''

  if phone_index !=-1:
    phone = original_text[phone_index + len(PHONE):email_index].strip()

    split = phone.split(',')
    # more elements means a contact name is provided
    if len(split) > 1:
      contact_name = split[0].strip()
      phone = split[1].strip()

    # check if email is provided
    if email_index!=-1:
      # email don't need to have uppercase
      email = original_text[email_index + len(OR_EMAIL):].strip().lower()

    phone_extension_index = phone.find(PHONE_EXTENSION)
    if phone_extension_index!=-1:
      phone_extension = phone[phone_extension_index + len(PHONE_EXTENSION):].strip()
      phone = phone[:phone_extension_index].strip()

  centre['contact_name'] = contact_name
  centre['phone'] = phone
  centre['phone_extension'] = phone_extension
  centre['email'] = email

# %%
EMAIL_DOMAIN_EXCLUSION = {'gmail.com', 'hotmail.com', 'rogers.com'}
EMAIL_AT_SIGN = '@'

def extract_website(centre, original_text):
  # format url, remove unnecessary prefix
  temp_string = (clean_text(original_text)
                        .replace('Website:', '')
                        .replace('https://', '')
                        .replace('http://', '')
                        .replace('www.', '')
                  .lower()) # website don't need to have uppercase

  # email can be input unexpectedly in the website field
  email_sign_index = temp_string.find(EMAIL_AT_SIGN)

  website = ''
  # check if the specific character was found
  if email_sign_index == -1:
    website = temp_string

  else:
    print(f'\tThis should be an email address: {temp_string}')

    # take into account this value as email if email is empty
    if centre['email'] == '':
      print(f'\tEmail:\t{temp_string}')
      centre['email'] = temp_string

    # slice the string from @ to the end
    # for example, someone@somecompany.com -> somecompany.com
    temp_string = temp_string[email_sign_index + 1:]

    # prevent email provider from being considered as a child care centre' website
    if temp_string not in EMAIL_DOMAIN_EXCLUSION:
      print(f'\tWebsite:\t{temp_string}, extracted from email')
      website = temp_string

  # remove the redundant '/' at the end (cosmetic reason)
  if website.endswith('/'):
    website = website[:-1]

  centre['website'] = website

# %%
def scrape_all_centres_detail(centre):
  url = centre['link']

  soup = get_requests(url)

  content = soup.find('div', class_='csd_opcrit_content_box')
  if not content:
    return {}

  address = content.find('p')
  if address:
    extract_address(centre, address.text)

  ul_tag = content.find('ul')
  if ul_tag:
    contact = ul_tag.find('li', class_='nudge')
    if contact:
      extract_contact(centre, contact.text)

    li_tags = ul_tag.find_all('li')
    if len(li_tags) > 1:
      website = li_tags[1]
      extract_website(centre, website.text)

# %%
import string
from time import sleep

LOWERCASE_ALPHABET = string.ascii_lowercase
SLEEP_TIME_IN_SECOND = 0.1
centres = []

for alphabet in LOWERCASE_ALPHABET:
  print(f'Start scraping centre list for alphabet {alphabet}.')
  alphabet_centres = scrape_all_centres_name_and_link(alphabet)
  centres.extend(alphabet_centres)
  print(f'\tFinish scraping {len(alphabet_centres)} centres with alphabet {alphabet}. Sleep for a short moment.')

  # incorporate a sleep in between requests as required
  sleep(SLEEP_TIME_IN_SECOND)

for index, centre in enumerate(centres):
  print(f'({index:04d}) Start scraping centre detail for centre {centre['name']}.')
  scrape_all_centres_detail(centre)
  print('\tFinish scraping. Sleep for a short moment.')

  # incorporate a sleep in between requests as required
  sleep(SLEEP_TIME_IN_SECOND)
# Out:
# Start scraping centre list for alphabet a.
# 	Finish scraping 58 centres with alphabet a. Sleep for a short moment.
# Start scraping centre list for alphabet b.
# 	Finish scraping 87 centres with alphabet b. Sleep for a short moment.
# Start scraping centre list for alphabet c.
# 	Finish scraping 88 centres with alphabet c. Sleep for a short moment.
# Start scraping centre list for alphabet d.
# 	Finish scraping 34 centres with alphabet d. Sleep for a short moment.
# Start scraping centre list for alphabet e.
# 	Finish scraping 33 centres with alphabet e. Sleep for a short moment.
# Start scraping centre list for alphabet f.
# 	Finish scraping 35 centres with alphabet f. Sleep for a short moment.
# Start scraping centre list for alphabet g.
# 	Finish scraping 55 centres with alphabet g. Sleep for a short moment.
# Start scraping centre list for alphabet h.
# 	Finish scraping 44 centres with alphabet h. Sleep for a short moment.
# Start scraping centre list for alphabet i.
# 	Finish scraping 9 centres with alphabet i. Sleep for a short moment.
# Start scraping centre list for alphabet j.
# 	Finish scraping 18 centres with alphabet j. Sleep for a short moment.
# Start scraping centre list for alphabet k.
# 	Finish scraping 47 centres with alphabet k. Sleep for a short moment.
# Start scraping centre list for alphabet l.
# 	Finish scraping 66 centres with alphabet l. Sleep for a short moment.
# Start scraping centre list for alphabet m.
# 	Finish scraping 84 centres with alphabet m. Sleep for a short moment.
# Start scraping centre list for alphabet n.
# 	Finish scraping 42 centres with alphabet n. Sleep for a short moment.
# Start scraping centre list for alphabet o.
# 	Finish scraping 20 centres with alphabet o. Sleep for a short moment.
# Start scraping centre list for alphabet p.
# 	Finish scraping 77 centres with alphabet p. Sleep for a short moment.
# Start scraping centre list for alphabet q.
# 	Finish scraping 3 centres with alphabet q. Sleep for a short moment.
# Start scraping centre list for alphabet r.
# 	Finish scraping 40 centres with alphabet r. Sleep for a short moment.
# Start scraping centre list for alphabet s.
# 	Finish scraping 96 centres with alphabet s. Sleep for a short moment.
# Start scraping centre list for alphabet t.
# 	Finish scraping 89 centres with alphabet t. Sleep for a short moment.
# Start scraping centre list for alphabet u.
# 	Finish scraping 10 centres with alphabet u. Sleep for a short moment.
# Start scraping centre list for alphabet v.
# 	Finish scraping 9 centres with alphabet v. Sleep for a short moment.
# Start scraping centre list for alphabet w.
# 	Finish scraping 48 centres with alphabet w. Sleep for a short moment.
# Start scraping centre list for alphabet x.
# 	No table found. Skip this URL: https://www.toronto.ca/data/children/dmc/a2z/a2zx.html
# 	Finish scraping 0 centres with alphabet x. Sleep for a short moment.
# Start scraping centre list for alphabet y.
# 	Finish scraping 14 centres with alphabet y. Sleep for a short moment.
# Start scraping centre list for alphabet z.
# 	No table found. Skip this URL: https://www.toronto.ca/data/children/dmc/a2z/a2zz.html
# 	Finish scraping 0 centres with alphabet z. Sleep for a short moment.
# (0000) Start scraping centre detail for centre A & A Daycare Centre.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Midland/Finch E.
# 	Finish scraping. Sleep for a short moment.
# (0001) Start scraping centre detail for centre Abacus Montessori Learning Centre.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0002) Start scraping centre detail for centre Abiona Centre For Infant And Early Mental Health Elc Broadview Campus.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Broadview/Mortimer
# 	Finish scraping. Sleep for a short moment.
# (0003) Start scraping centre detail for centre Abiona Centre For Infant And Early Mental Health Elc Humewood Campus.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Christie/St. Clair
# 	Finish scraping. Sleep for a short moment.
# (0004) Start scraping centre detail for centre Aboriginal Head Start - Epnigishmok.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (0005) Start scraping centre detail for centre Absorbent Minds (Op1756925 Ontario Inc.).
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Old Kingston Rd./Morningside
# 	Finish scraping. Sleep for a short moment.
# (0006) Start scraping centre detail for centre Absorbent Minds 2.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Old Kingston Rd./Morningside
# 	Finish scraping. Sleep for a short moment.
# (0007) Start scraping centre detail for centre Absorbent Years Childcare (Montessori).
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview Ave/Macdonald-Cartier
# 	Finish scraping. Sleep for a short moment.
# (0008) Start scraping centre detail for centre Absorbent Years Childcare Inc.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Sheppard Ave E/Don Mills Rd
# 	Finish scraping. Sleep for a short moment.
# (0009) Start scraping centre detail for centre After Four Children's Enrichment Program.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Ellesmere/Pharmacy
# 	Finish scraping. Sleep for a short moment.
# (0010) Start scraping centre detail for centre Agape Christian Montessori School (2236800 Ontario Inc.).
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Midland Ave/McNicoll Ave
# 	Finish scraping. Sleep for a short moment.
# (0011) Start scraping centre detail for centre Agile Innovators Montessori.
# 	Ward:	Scarborough-Agincourt
# 	Finish scraping. Sleep for a short moment.
# (0012) Start scraping centre detail for centre Agincourt Montessori School Inc..
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Midland/Sheppard E.
# 	Finish scraping. Sleep for a short moment.
# (0013) Start scraping centre detail for centre Agincourt Temple Day Care(Governing Council Of The Salvation Army).
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Birchmount/Finch E.
# 	Finish scraping. Sleep for a short moment.
# (0014) Start scraping centre detail for centre Air-O-Down Child Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Wilson/Keele
# 	Finish scraping. Sleep for a short moment.
# (0015) Start scraping centre detail for centre Albion Early Learning  & Child Care Centre.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Albion/Kipling
# 	Finish scraping. Sleep for a short moment.
# (0016) Start scraping centre detail for centre Albion Heights School Age YMCA.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Finch W./Martingrove
# 	Finish scraping. Sleep for a short moment.
# (0017) Start scraping centre detail for centre Alderwood Action After School.
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Horner/Browns Line
# 	Finish scraping. Sleep for a short moment.
# (0018) Start scraping centre detail for centre Alexander Muir Gladstone Jr YMCA.
# 	Ward:	Davenport
# 	Cross Street Reference:	Queen W./Dufferin
# 	Finish scraping. Sleep for a short moment.
# (0019) Start scraping centre detail for centre Alexandra Park Early Learning & Child Care Centre.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Dundas/Spadina
# 	Finish scraping. Sleep for a short moment.
# (0020) Start scraping centre detail for centre Alive Montessori & Private School.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Eglinton Ave W/Bathurst
# 	Finish scraping. Sleep for a short moment.
# (0021) Start scraping centre detail for centre All About Kids Inc. (1055 Gerrard Street East).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Gerrard/Jones
# 	Finish scraping. Sleep for a short moment.
# (0022) Start scraping centre detail for centre All About Kids Sheppard.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Sheppard E./Victoria Park
# 	Finish scraping. Sleep for a short moment.
# (0023) Start scraping centre detail for centre Allenby Day Care.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Eglinton W./Avenue Rd.
# 	Finish scraping. Sleep for a short moment.
# (0024) Start scraping centre detail for centre All My Children Child Care.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Finch E./McCowan
# 	Finish scraping. Sleep for a short moment.
# (0025) Start scraping centre detail for centre Alphabet Academy.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (0026) Start scraping centre detail for centre Alphabet Station.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0027) Start scraping centre detail for centre Alphabet Treehouse Childcare Centre.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Avenue Rd/Wilson Ave
# 	Finish scraping. Sleep for a short moment.
# (0028) Start scraping centre detail for centre Alternative Primary School Parent Group.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Spadina/Eglinton W.
# 	Finish scraping. Sleep for a short moment.
# (0029) Start scraping centre detail for centre Alvin Curling YMCA.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Sheppard/Morningside
# 	Finish scraping. Sleep for a short moment.
# (0030) Start scraping centre detail for centre Ancaster Early Learning & Child Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Wilson/Dufferin
# 	Finish scraping. Sleep for a short moment.
# (0031) Start scraping centre detail for centre Ancaster Public School, Extended Day Program.
# 	Ward:	York Centre
# 	Cross Street Reference:	Wilson/Dufferin
# 	Finish scraping. Sleep for a short moment.
# (0032) Start scraping centre detail for centre Angelgate Daycare Inc..
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Runnymede/Annette
# 	Finish scraping. Sleep for a short moment.
# (0033) Start scraping centre detail for centre Angelgate Daycare Ltd. 230 Jane Street.
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Jane St/Annette St
# 	Finish scraping. Sleep for a short moment.
# (0034) Start scraping centre detail for centre Angelgate Daycare Ltd. 232 Jane Street.
# 	Ward:	Parkdale-High Park
# 	Finish scraping. Sleep for a short moment.
# (0035) Start scraping centre detail for centre Angus Valley Montessori.
# 	Ward:	Willowdale
# 	Finish scraping. Sleep for a short moment.
# (0036) Start scraping centre detail for centre Annex Montessori School.
# 	Ward:	University-Rosedale
# 	Finish scraping. Sleep for a short moment.
# (0037) Start scraping centre detail for centre Annunciation Catholic School Before & After Child Care Program.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Cassandra Blvd/Victoria Park
# 	Finish scraping. Sleep for a short moment.
# (0038) Start scraping centre detail for centre Antica Village Children's Day Care Centre (646508 Ontario Ltd).
# 	Ward:	Humber River-Black Creek
# 	Cross Street Reference:	Steeles W./Jane
# 	Finish scraping. Sleep for a short moment.
# (0039) Start scraping centre detail for centre A Place To Play Nursery School Of Bloor West Village.
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Annette/Jane
# 	Finish scraping. Sleep for a short moment.
# (0040) Start scraping centre detail for centre Apple Day Care Centre.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Markham Rd/Eglinton Ave E
# 	Finish scraping. Sleep for a short moment.
# (0041) Start scraping centre detail for centre Apple Jacks Preschool.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0042) Start scraping centre detail for centre Aquabella Child Care.
# 	Ward:	Spadina-Fort York
# 	Finish scraping. Sleep for a short moment.
# (0043) Start scraping centre detail for centre Arbor Glen Community Child Care Centre.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Steeles E./Don Mills
# 	Finish scraping. Sleep for a short moment.
# (0044) Start scraping centre detail for centre Armour Heights Child Care Program.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Wilson/Avenue Rd.
# 	Finish scraping. Sleep for a short moment.
# (0045) Start scraping centre detail for centre Ars Nursery School - Armenian Community Centre.
# 	Ward:	Don Valley North
# 	Finish scraping. Sleep for a short moment.
# (0046) Start scraping centre detail for centre Ascot Avenue Community Daycare.
# 	Ward:	Davenport
# 	Cross Street Reference:	St Clair Ave W/Oakwood Ave
# 	Finish scraping. Sleep for a short moment.
# (0047) Start scraping centre detail for centre Ascot Avenue Community Day Care.
# 	Ward:	Davenport
# 	Cross Street Reference:	Davenport/Dufferin
# 	Finish scraping. Sleep for a short moment.
# (0048) Start scraping centre detail for centre Aspiring Academics Preschool Inc..
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0049) Start scraping centre detail for centre Aspiring Academics Preschool - Kingston.
# 	Ward:	Scarborough Southwest
# 	Finish scraping. Sleep for a short moment.
# (0050) Start scraping centre detail for centre Aspiring Academics Preschool - Somerset.
# 	Ward:	Davenport
# 	Cross Street Reference:	Davenport Rd/Somerset Ave
# 	Finish scraping. Sleep for a short moment.
# (0051) Start scraping centre detail for centre Atelier Childcare Inc..
# 	Ward:	Parkdale-High Park
# 	Finish scraping. Sleep for a short moment.
# (0052) Start scraping centre detail for centre Atelier Kids Inc..
# 	Ward:	Parkdale-High Park
# 	Finish scraping. Sleep for a short moment.
# (0053) Start scraping centre detail for centre Athletic Montessori Academy.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Danforth Ave/Pape Ave
# 	Finish scraping. Sleep for a short moment.
# (0054) Start scraping centre detail for centre Avalon Children's Montessori School.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Kingston Rd./Warden
# 	Finish scraping. Sleep for a short moment.
# (0055) Start scraping centre detail for centre Avenue Road Nursery School.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Avenue Rd./Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0056) Start scraping centre detail for centre Avondale Centre For Early Development.
# 	Ward:	Willowdale
# 	Finish scraping. Sleep for a short moment.
# (0057) Start scraping centre detail for centre Avondale Public School, Extended Day Program.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Willowdale Ave/Sheppard Ave
# 	Finish scraping. Sleep for a short moment.
# (0058) Start scraping centre detail for centre B.F. Toronto Centre For Early Childhood Education.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Islington/Hwy. 401
# 	Finish scraping. Sleep for a short moment.
# (0059) Start scraping centre detail for centre Bais Yaakov Elementary School.
# 	Ward:	Eglinton-Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0060) Start scraping centre detail for centre Balmy Beach Community Day Care Centre.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Kingston Rd./Victoria Park
# 	Finish scraping. Sleep for a short moment.
# (0061) Start scraping centre detail for centre Bannockburn School.
# 	Ward:	Willowdale
# 	Finish scraping. Sleep for a short moment.
# (0062) Start scraping centre detail for centre Banting And Best Child Care Centre (380 Goldhawk).
# 	Ward:	Scarborough North
# 	Cross Street Reference:	McCowan/McNicoll
# 	Finish scraping. Sleep for a short moment.
# (0063) Start scraping centre detail for centre Banting And Best Schoolage Satellite(255 Alton Towers).
# 	Ward:	Scarborough North
# 	Cross Street Reference:	McCowan/McNicoll
# 	Finish scraping. Sleep for a short moment.
# (0064) Start scraping centre detail for centre Baycrest Child Care Centre.
# 	Ward:	Eglinton-Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0065) Start scraping centre detail for centre Bayview Gardens Day Care Centre.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Bayview/Finch
# 	Finish scraping. Sleep for a short moment.
# (0066) Start scraping centre detail for centre Bayview Glen.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Don Mills Rd/York Mills Rd
# 	Finish scraping. Sleep for a short moment.
# (0067) Start scraping centre detail for centre Beaches Montessori School Incorporated.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0068) Start scraping centre detail for centre Beaches Montessori School South.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0069) Start scraping centre detail for centre Beach Hill Montessori.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0070) Start scraping centre detail for centre Beamish Academy.
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Bloor St W/Kipling Ave
# 	Finish scraping. Sleep for a short moment.
# (0071) Start scraping centre detail for centre Beatty Buddies Daycare.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Danforth/Coxwell
# 	Finish scraping. Sleep for a short moment.
# (0072) Start scraping centre detail for centre Beechgrove Sunshine Child Care.
# 	Ward:	Scarborough-Rouge Park
# 	Finish scraping. Sleep for a short moment.
# (0073) Start scraping centre detail for centre Bendale Licensed Before And After School Program.
# 	Ward:	Scarborough-Guildwood
# 	Finish scraping. Sleep for a short moment.
# (0074) Start scraping centre detail for centre Bennington Heights Child Care Centre.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview/Moore
# 	Finish scraping. Sleep for a short moment.
# (0075) Start scraping centre detail for centre Berner Trail Early Learning & Child Care Centre.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Neilson/Sheppard
# 	Finish scraping. Sleep for a short moment.
# (0076) Start scraping centre detail for centre Berner Trail Junior Public School, Extended Day Program.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Neilson/Sheppard
# 	Finish scraping. Sleep for a short moment.
# (0077) Start scraping centre detail for centre Bessborough Child Care Centre.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (0078) Start scraping centre detail for centre Beth Sholom First Foundations Community Preschool.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (0079) Start scraping centre detail for centre Beverly Glen YMCA.
# 	Ward:	Scarborough-Agincourt
# 	Finish scraping. Sleep for a short moment.
# (0080) Start scraping centre detail for centre Big Bears Daycare.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Sheppard/Kingston Rd.
# 	Finish scraping. Sleep for a short moment.
# (0081) Start scraping centre detail for centre Big Dreams Early Learning Centre.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Victoria Park Ave/Lawrence.
# 	Finish scraping. Sleep for a short moment.
# (0082) Start scraping centre detail for centre Birch Cliff Heights Licensed Before And After School Program.
# 	Ward:	Scarborough Southwest
# 	Finish scraping. Sleep for a short moment.
# (0083) Start scraping centre detail for centre Birch Cliff Public School, Extended Day Program.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Birchmount/Danforth
# 	Finish scraping. Sleep for a short moment.
# (0084) Start scraping centre detail for centre Birchmount Bluffs Neighbourhood Centre Community Nursery School.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Birchmount/Danforth Ave.
# 	Finish scraping. Sleep for a short moment.
# (0085) Start scraping centre detail for centre Birchmount Place Centre For Early Learning.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Birchmount/Sheppard E.
# 	Finish scraping. Sleep for a short moment.
# (0086) Start scraping centre detail for centre Birds And Bees Day Care Centre.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Kennedy/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (0087) Start scraping centre detail for centre Blacksmith Child Care Centre.
# 	Ward:	Humber River-Black Creek
# 	Cross Street Reference:	Jane/Steeles
# 	Finish scraping. Sleep for a short moment.
# (0088) Start scraping centre detail for centre Blake Street Early Learning & Child Care Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Jones/Danforth
# 	Finish scraping. Sleep for a short moment.
# (0089) Start scraping centre detail for centre Blake Street Junior Public School, Extended Day Program.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Jones/Gerrard
# 	Finish scraping. Sleep for a short moment.
# (0090) Start scraping centre detail for centre Blaydon Community Day Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Keele/Wilson
# 	Finish scraping. Sleep for a short moment.
# (0091) Start scraping centre detail for centre Blessed Pier Giorgio Frassati Extended Day Program.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Markham Rd/Steeles Ave E
# 	Finish scraping. Sleep for a short moment.
# (0092) Start scraping centre detail for centre Blessed Trinity Before & After School.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Bayview/Finch
# 	Finish scraping. Sleep for a short moment.
# (0093) Start scraping centre detail for centre Bloomsbury Academy.
# 	Ward:	Toronto Centre
# 	Finish scraping. Sleep for a short moment.
# (0094) Start scraping centre detail for centre Bloorcourt Village Early Learning Centre.
# 	Ward:	Davenport
# 	Cross Street Reference:	Bloor W./Dovercourt
# 	Finish scraping. Sleep for a short moment.
# (0095) Start scraping centre detail for centre Bloor West Nursery School.
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Runnymede/Annette St.
# 	Finish scraping. Sleep for a short moment.
# (0096) Start scraping centre detail for centre Blossoming Minds Learning Centre Inc..
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0097) Start scraping centre detail for centre Blue Bell Academy.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Main St/Gerrard St
# 	Finish scraping. Sleep for a short moment.
# (0098) Start scraping centre detail for centre Blue Bell Academy Inc..
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Gerrard St E/Main St
# 	Finish scraping. Sleep for a short moment.
# (0099) Start scraping centre detail for centre Blue Bell Academy Inc..
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0100) Start scraping centre detail for centre Bluebird Montessori School (Mini).
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0101) Start scraping centre detail for centre Bluebird Montessori School South.
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0102) Start scraping centre detail for centre Blue Butterfly Montessori School Inc..
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Richmond W./John St.
# 	Finish scraping. Sleep for a short moment.
# (0103) Start scraping centre detail for centre Blue Wave Child Care Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Lawrence/Don Mills
# 	Finish scraping. Sleep for a short moment.
# (0104) Start scraping centre detail for centre Bluffer's Park Montessori School.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Kingston Rd/St. Clair Ave. E
# 	Finish scraping. Sleep for a short moment.
# (0105) Start scraping centre detail for centre Boardwalk Montessori School Inc..
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Queen/Woodbine
# 	Finish scraping. Sleep for a short moment.
# (0106) Start scraping centre detail for centre Bonaventure Child Care Centre.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Dufferin/King St. W.
# 	Finish scraping. Sleep for a short moment.
# (0107) Start scraping centre detail for centre Boulton Avenue Child Care Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Broadview/Queen
# 	Finish scraping. Sleep for a short moment.
# (0108) Start scraping centre detail for centre Bowmore.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Gerrard/Coxwell
# 	Finish scraping. Sleep for a short moment.
# (0109) Start scraping centre detail for centre Bowmore Road Junior And Senior Public School, Extended Day Program.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Gerrard/Coxwell
# 	Finish scraping. Sleep for a short moment.
# (0110) Start scraping centre detail for centre Braeburn Woods Day Care Centre.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Albion/Weston Rd
# 	Finish scraping. Sleep for a short moment.
# (0111) Start scraping centre detail for centre Brahms Early Learning & Child Care Centre.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Don Mills/Finch
# 	Finish scraping. Sleep for a short moment.
# (0112) Start scraping centre detail for centre Branson Pre-School Ltd..
# 	Ward:	York Centre
# 	Cross Street Reference:	Bathurst/Finch
# 	Finish scraping. Sleep for a short moment.
# (0113) Start scraping centre detail for centre Brian's Petit Amis.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Brian/Sheppard
# 	Finish scraping. Sleep for a short moment.
# (0114) Start scraping centre detail for centre Brian Drive School Age Program (YMCA).
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Victoria Park/Sheppard
# 	Finish scraping. Sleep for a short moment.
# (0115) Start scraping centre detail for centre Briarcrest Child Care.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Rathburn/Renforth
# 	Finish scraping. Sleep for a short moment.
# (0116) Start scraping centre detail for centre Bridlegrove Daycare Centre.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Pharmacy/Finch
# 	Finish scraping. Sleep for a short moment.
# (0117) Start scraping centre detail for centre Bridlewood Jr YMCA.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Huntingwood/Warden
# 	Finish scraping. Sleep for a short moment.
# (0118) Start scraping centre detail for centre Bright Minds Childcare & Montessori School.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	O'Connor Dr./Bermondsey
# 	Finish scraping. Sleep for a short moment.
# (0119) Start scraping centre detail for centre Brightpath Academy - Davisville Village.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview Ave/Davisville Ave
# 	Finish scraping. Sleep for a short moment.
# (0120) Start scraping centre detail for centre Brightpath Academy - Forest Hill.
# 	Ward:	Eglinton-Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0121) Start scraping centre detail for centre Brightpath Academy - Leaside.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Laird/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (0122) Start scraping centre detail for centre Brightpath Academy - The Beach.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0123) Start scraping centre detail for centre Brightpath Academy - The Beach Clubzone.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0124) Start scraping centre detail for centre Brightpath Academy - Wanless Park (18).
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Yonge/Lawrence E.
# 	Finish scraping. Sleep for a short moment.
# (0125) Start scraping centre detail for centre Brightpath Academy - Wanless Park (20).
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Yonge/Lawrence E.
# 	Finish scraping. Sleep for a short moment.
# (0126) Start scraping centre detail for centre Brightpath Eglinton.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Eglinton Ave/Centennial Park
# 	Finish scraping. Sleep for a short moment.
# (0127) Start scraping centre detail for centre Brightpath Leslieville.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Carlaw Ave/Queen St E
# 	Finish scraping. Sleep for a short moment.
# (0128) Start scraping centre detail for centre Brimley Bloom Montessori.
# 	Ward:	Scarborough Centre
# 	Finish scraping. Sleep for a short moment.
# (0129) Start scraping centre detail for centre Brimwood School Age YMCA.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Brimley/Finch
# 	Finish scraping. Sleep for a short moment.
# (0130) Start scraping centre detail for centre Broadacres Junior School, Extended Day Program.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Renforth/Burnhamthorpe
# 	Finish scraping. Sleep for a short moment.
# (0131) Start scraping centre detail for centre Broadlands School Age Program YMCA.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Victoria Park/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0132) Start scraping centre detail for centre Broad View French Montessori School.
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0133) Start scraping centre detail for centre Broad View French Montessori School II Limited.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Kingston Rd./Fallingbrook
# 	Finish scraping. Sleep for a short moment.
# (0134) Start scraping centre detail for centre Brock Early Learning Centre.
# 	Ward:	Davenport
# 	Cross Street Reference:	College/Dufferin
# 	Finish scraping. Sleep for a short moment.
# (0135) Start scraping centre detail for centre Brookhaven Child Care.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Black Creek/Lawrence W.
# 	Finish scraping. Sleep for a short moment.
# (0136) Start scraping centre detail for centre Brookhaven Child Care -  St. Bernard Site.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Jane/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0137) Start scraping centre detail for centre Brookmill Boulevard Junior Public School, Extended Day Program.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Warden Ave/Finch Ave E
# 	Finish scraping. Sleep for a short moment.
# (0138) Start scraping centre detail for centre Brookside Child Care Centre.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Tapscott Rd./Passmore Ave.
# 	Finish scraping. Sleep for a short moment.
# (0139) Start scraping centre detail for centre Bruce Woodgreen Early Learning Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Pape/Queen
# 	Finish scraping. Sleep for a short moment.
# (0140) Start scraping centre detail for centre Buchanan Extended Day & School Age Program.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Warden Ave/Lawrence Ave E
# 	Finish scraping. Sleep for a short moment.
# (0141) Start scraping centre detail for centre Buds And Blossoms.
# 	Ward:	Toronto Centre
# 	Finish scraping. Sleep for a short moment.
# (0142) Start scraping centre detail for centre Bumble Bee Academy.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (0143) Start scraping centre detail for centre Bumble Bee Academy.
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0144) Start scraping centre detail for centre Bumble Bee Garden Child Care Ltd..
# 	Ward:	Davenport
# 	Finish scraping. Sleep for a short moment.
# (0145) Start scraping centre detail for centre C.A.S.P. Catholic After School Program.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Lawrence Ave. W./Keele
# 	Finish scraping. Sleep for a short moment.
# (0146) Start scraping centre detail for centre C.D.Farquharson Jr YMCA.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Brimley/Pitfield
# 	Finish scraping. Sleep for a short moment.
# (0147) Start scraping centre detail for centre Calico Saints Child Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Sheppard W./Jane
# 	Finish scraping. Sleep for a short moment.
# (0148) Start scraping centre detail for centre Cambridge Leaf Montessori School.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Markham Rd/McNicoll Ave
# 	Finish scraping. Sleep for a short moment.
# (0149) Start scraping centre detail for centre Cambridge Place Centre For Early Learning.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Victoria Park/Danforth Ave.
# 	Finish scraping. Sleep for a short moment.
# (0150) Start scraping centre detail for centre Campus Community Co-Operative Day Care.
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	Bloor/St. George
# 	Finish scraping. Sleep for a short moment.
# (0151) Start scraping centre detail for centre Canadiana Court Early Learning & Child Care Centre.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Midland/Danforth
# 	Finish scraping. Sleep for a short moment.
# (0152) Start scraping centre detail for centre Candy Factory Swallows Day Care (The).
# 	Ward:	Davenport
# 	Cross Street Reference:	Bloor W./Symington
# 	Finish scraping. Sleep for a short moment.
# (0153) Start scraping centre detail for centre Cardinal Leger Child Care Centre (Scarborough).
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Ellesmere/Morningside
# 	Finish scraping. Sleep for a short moment.
# (0154) Start scraping centre detail for centre Carefree Preschool.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Dixon/Kipling
# 	Finish scraping. Sleep for a short moment.
# (0155) Start scraping centre detail for centre Carleton Village Early Learning Centre.
# 	Ward:	Davenport
# 	Cross Street Reference:	Davenport/Symington
# 	Finish scraping. Sleep for a short moment.
# (0156) Start scraping centre detail for centre Carmelite Missionary Sisters Of Saint Theresa Of The Child Jesus.
# 	Ward:	York Centre
# 	Cross Street Reference:	Keele/Wilson
# 	Finish scraping. Sleep for a short moment.
# (0157) Start scraping centre detail for centre Carousel Child Care Development Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Finch W./Wilmington
# 	Finish scraping. Sleep for a short moment.
# (0158) Start scraping centre detail for centre Casa Del Zotto Children's Centre.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Dufferin/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0159) Start scraping centre detail for centre Casa Vera Montessori School.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Keele St./Gulliver Rd.
# 	Finish scraping. Sleep for a short moment.
# (0160) Start scraping centre detail for centre Cast For Kids Child Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Sheppard W./Keele
# 	Finish scraping. Sleep for a short moment.
# (0161) Start scraping centre detail for centre Castlebar YMCA.
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Islington Ave/Ambleside Ave
# 	Finish scraping. Sleep for a short moment.
# (0162) Start scraping centre detail for centre Castle Park Playschool.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Queen E/Woodbine
# 	Finish scraping. Sleep for a short moment.
# (0163) Start scraping centre detail for centre Caterpillar & Co.
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Kipling/Norseman
# 	Finish scraping. Sleep for a short moment.
# (0164) Start scraping centre detail for centre Cedarbrae Day Nurseries (20 Greencrest).
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Markham/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0165) Start scraping centre detail for centre Cedarbrae Day Nursery.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Midland/Lawrence E.
# 	Finish scraping. Sleep for a short moment.
# (0166) Start scraping centre detail for centre Cedarbrae Day Nursery (1375 Midland).
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Midland/Lawrence E.
# 	Finish scraping. Sleep for a short moment.
# (0167) Start scraping centre detail for centre Cedarvale Community School, Extended Day Program.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Glen Cedar Road/Ava Road
# 	Finish scraping. Sleep for a short moment.
# (0168) Start scraping centre detail for centre Centenary Seven Oaks  Early Learning & Child Care Centre.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Ellesmere/Neilson Rd.
# 	Finish scraping. Sleep for a short moment.
# (0169) Start scraping centre detail for centre Centennial College Early Childhood Education Centre(550 Mortimer).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Mortimer/Coxwell
# 	Finish scraping. Sleep for a short moment.
# (0170) Start scraping centre detail for centre Centennial College East York Day Care (Plains Rd).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Coxwell/O'Connor
# 	Finish scraping. Sleep for a short moment.
# (0171) Start scraping centre detail for centre Centennial College Progress Campus Child Care Centre.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Markham/Hwy. 401
# 	Finish scraping. Sleep for a short moment.
# (0172) Start scraping centre detail for centre Centennial Infant And Child Centre.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Yonge/St. Clair
# 	Finish scraping. Sleep for a short moment.
# (0173) Start scraping centre detail for centre Central Eglinton Childrens' Centre.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Eglinton/Mt. Pleasant
# 	Finish scraping. Sleep for a short moment.
# (0174) Start scraping centre detail for centre Central Montessori School.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Yonge St/Sheppard Ave E
# 	Finish scraping. Sleep for a short moment.
# (0175) Start scraping centre detail for centre Central Montessori Schools - Maplehurst Campus.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Sheppard Ave E/Willowdale Ave
# 	Finish scraping. Sleep for a short moment.
# (0176) Start scraping centre detail for centre Central Montessori Schools - Willowdale Campus.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Willowdale Ave./Sheppard E.
# 	Finish scraping. Sleep for a short moment.
# (0177) Start scraping centre detail for centre Central Montessori Schools - York Mills Campus.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Leslie/York Mills
# 	Finish scraping. Sleep for a short moment.
# (0178) Start scraping centre detail for centre Centre De La Petite Enfance - Les Amis Du Monde.
# 	Ward:	Davenport
# 	Cross Street Reference:	Dundas/Dupont
# 	Finish scraping. Sleep for a short moment.
# (0179) Start scraping centre detail for centre Centro Clinton Day Care Centre.
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	College/Bathurst
# 	Finish scraping. Sleep for a short moment.
# (0180) Start scraping centre detail for centre Chabad Lubavitch Of York Mills.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview Ave/York Mills Rd
# 	Finish scraping. Sleep for a short moment.
# (0181) Start scraping centre detail for centre Chabad Of Midtown.
# 	Ward:	Davenport
# 	Finish scraping. Sleep for a short moment.
# (0182) Start scraping centre detail for centre Chabad Of Midtown - Bathurst.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Bathurst/Davenport Rd
# 	Finish scraping. Sleep for a short moment.
# (0183) Start scraping centre detail for centre Chabad Of Midtown - St Clair.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (0184) Start scraping centre detail for centre Champions Children's Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Don Mills/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (0185) Start scraping centre detail for centre Charlottetown Blvd. Childcare Centre.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Port Union Rd./Hwy. 401
# 	Finish scraping. Sleep for a short moment.
# (0186) Start scraping centre detail for centre Charlottetown Kindergarten Extended Care Program.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Charlottetown Blvd/Centennial
# 	Finish scraping. Sleep for a short moment.
# (0187) Start scraping centre detail for centre Chartland Child Care Inc.
# 	Ward:	Scarborough North
# 	Cross Street Reference:	Brimley/Huntingwood
# 	Finish scraping. Sleep for a short moment.
# (0188) Start scraping centre detail for centre Cheer Day Care Centre.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Kennedy/McNicoll
# 	Finish scraping. Sleep for a short moment.
# (0189) Start scraping centre detail for centre Chester Jr YMCA.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Broadview/Gowan
# 	Finish scraping. Sleep for a short moment.
# (0190) Start scraping centre detail for centre Chester Le Early Learning & Child Care Centre.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Victoria Park/Finch Ave E
# 	Finish scraping. Sleep for a short moment.
# (0191) Start scraping centre detail for centre Children's Circle Of St. Barnabas.
# 	Ward:	Toronto-Danforth
# 	Finish scraping. Sleep for a short moment.
# (0192) Start scraping centre detail for centre Children's Creative Corner Co-Op Nursery School.
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Runnymede/Bloor
# 	Finish scraping. Sleep for a short moment.
# (0193) Start scraping centre detail for centre Children's Garden Junior School - Early Start.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Eglinton E./Bayview
# 	Finish scraping. Sleep for a short moment.
# (0194) Start scraping centre detail for centre Children's Garden Nursery School.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Bayview Ave/Eglinton Ave E
# 	Finish scraping. Sleep for a short moment.
# (0195) Start scraping centre detail for centre Children's Land Learning Centre Inc..
# 	Ward:	Scarborough-Rouge Park
# 	Finish scraping. Sleep for a short moment.
# (0196) Start scraping centre detail for centre Children's Magic Moments Child Care And Nursery School.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Avenue Rd./Eglinton W.
# 	Finish scraping. Sleep for a short moment.
# (0197) Start scraping centre detail for centre Children's Playgarden /Toronto Military Family Resource Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	William R. Allen/Sheppard W.
# 	Finish scraping. Sleep for a short moment.
# (0198) Start scraping centre detail for centre Children's Primary Centre.
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	Beverley/College
# 	Finish scraping. Sleep for a short moment.
# (0199) Start scraping centre detail for centre Children's Village Day Care Centre #1.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Markham/Ellesmere
# 	Finish scraping. Sleep for a short moment.
# (0200) Start scraping centre detail for centre Children's Village Day Care Centre #3.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Markham/Eglinton E.
# 	Finish scraping. Sleep for a short moment.
# (0201) Start scraping centre detail for centre Children Are People Education.
# 	Ward:	York Centre
# 	Cross Street Reference:	Sheppard/Wilson Heights
# 	Finish scraping. Sleep for a short moment.
# (0202) Start scraping centre detail for centre Children Of Tomorrow.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	McCowan Rd/Eglinton Ave E
# 	Finish scraping. Sleep for a short moment.
# (0203) Start scraping centre detail for centre Children Of Tomorrow - John McCrae.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Danforth Rd/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (0204) Start scraping centre detail for centre Childspace Day Care Corporation # 1 (50 Woodmount).
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Danforth Ave./Woodbine
# 	Finish scraping. Sleep for a short moment.
# (0205) Start scraping centre detail for centre Childspace Day Care Corporation # 2 (690 Carlaw).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Carlaw/Danforth Ave
# 	Finish scraping. Sleep for a short moment.
# (0206) Start scraping centre detail for centre Childspace Day Care Corporation # 3 (49 Felstead Avenue).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Danforth Ave./Greenwood
# 	Finish scraping. Sleep for a short moment.
# (0207) Start scraping centre detail for centre Chine Drive Licensed Before And After School Program.
# 	Ward:	Scarborough Southwest
# 	Finish scraping. Sleep for a short moment.
# (0208) Start scraping centre detail for centre Churchill Chums School Age Child Care Centre.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Senlac/Finch
# 	Finish scraping. Sleep for a short moment.
# (0209) Start scraping centre detail for centre Church Street School Day Care Service Inc..
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Church/Carlton
# 	Finish scraping. Sleep for a short moment.
# (0210) Start scraping centre detail for centre City Kids Early Learning & Child Care Centre.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Bathurst/Front St. W.
# 	Finish scraping. Sleep for a short moment.
# (0211) Start scraping centre detail for centre Clairlea Child Care Centre.
# 	Ward:	Scarborough Southwest
# 	Finish scraping. Sleep for a short moment.
# (0212) Start scraping centre detail for centre Clearview Child Care Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Don Mills Rd/Bond Avenue
# 	Finish scraping. Sleep for a short moment.
# (0213) Start scraping centre detail for centre Cliffwood Community Child Care.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Don Mills/Steeles E.
# 	Finish scraping. Sleep for a short moment.
# (0214) Start scraping centre detail for centre Cole Street Early Learning & Child Care Centre.
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Parliament/Dundas
# 	Finish scraping. Sleep for a short moment.
# (0215) Start scraping centre detail for centre Columbus Early Learning Centres.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Keele/Hwy. 401
# 	Finish scraping. Sleep for a short moment.
# (0216) Start scraping centre detail for centre Columbus Early Learning Centres - Regina Mundi.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Dufferin/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (0217) Start scraping centre detail for centre Columbus Early Learning Centres - St Charles.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Lawrence Ave W/Dufferin St
# 	Finish scraping. Sleep for a short moment.
# (0218) Start scraping centre detail for centre Columbus Early Learning - St Raphael.
# 	Ward:	York Centre
# 	Cross Street Reference:	Keele St/Wilson St
# 	Finish scraping. Sleep for a short moment.
# (0219) Start scraping centre detail for centre Community Centre 55-Adam Beck.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Victoria Park/Gerrard E.
# 	Finish scraping. Sleep for a short moment.
# (0220) Start scraping centre detail for centre Community Centre 55 - Children Services (97 Main Street).
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Main/Gerrard
# 	Finish scraping. Sleep for a short moment.
# (0221) Start scraping centre detail for centre Community Centre 55 - Kimberly Public School.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Main/Gerrard
# 	Finish scraping. Sleep for a short moment.
# (0222) Start scraping centre detail for centre Community Centre 55 -Ted Reeves Arena.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Main/Gerrard
# 	Finish scraping. Sleep for a short moment.
# (0223) Start scraping centre detail for centre Cottingham Child Care Centre.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Yonge/Summerhill
# 	Finish scraping. Sleep for a short moment.
# (0224) Start scraping centre detail for centre Cougar Court Child Care Centre 15.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Eglinton E./Markham
# 	Finish scraping. Sleep for a short moment.
# (0225) Start scraping centre detail for centre Cougar Court Child Care Centre 25.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Eglinton E./Markham
# 	Finish scraping. Sleep for a short moment.
# (0226) Start scraping centre detail for centre Courtleigh Place Child Care Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Don Mills/York Mills
# 	Finish scraping. Sleep for a short moment.
# (0227) Start scraping centre detail for centre Coxwell Early Learning & Child Care Centre.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Queen E./Coxwell
# 	Finish scraping. Sleep for a short moment.
# (0228) Start scraping centre detail for centre Creative Minds Montessori Academy.
# 	Ward:	Scarborough-Rouge Park
# 	Finish scraping. Sleep for a short moment.
# (0229) Start scraping centre detail for centre Crestview School Age Program YMCA.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Don Mills/Finch
# 	Finish scraping. Sleep for a short moment.
# (0230) Start scraping centre detail for centre Curious Caterpillars - College View.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Avenue Rd/Eglinton Ave W
# 	Finish scraping. Sleep for a short moment.
# (0231) Start scraping centre detail for centre Curious Caterpillars - Petman Avenue.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Eglinton/Mt. Pleasant
# 	Finish scraping. Sleep for a short moment.
# (0232) Start scraping centre detail for centre Curlew Montessori School.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Lawrence E./Victoria Park
# 	Finish scraping. Sleep for a short moment.
# (0233) Start scraping centre detail for centre Dalemount Child Care.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Glencairn Ave./Bathurst
# 	Finish scraping. Sleep for a short moment.
# (0234) Start scraping centre detail for centre Dandylion Childcare Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Donlands/Danforth Ave.
# 	Finish scraping. Sleep for a short moment.
# (0235) Start scraping centre detail for centre Danforth Early Learning & Child Care Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Danforth Ave./Greenwood Ave.
# 	Finish scraping. Sleep for a short moment.
# (0236) Start scraping centre detail for centre Danforth Gardens Playcare.
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Birchmount Rd/Danforth Rd
# 	Finish scraping. Sleep for a short moment.
# (0237) Start scraping centre detail for centre Davenport Perth Early Learning & Child Care Centre.
# 	Ward:	Davenport
# ...
# 	Finish scraping. Sleep for a short moment.
# (1022) Start scraping centre detail for centre Trust Child Care Inc..
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Yonge St/Summerhill
# 	Finish scraping. Sleep for a short moment.
# (1023) Start scraping centre detail for centre Tumpane Child Care Learning Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Jane/Wilson
# 	Finish scraping. Sleep for a short moment.
# (1024) Start scraping centre detail for centre Two Short Storeys.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Broadview/Victor Ave
# 	Finish scraping. Sleep for a short moment.
# (1025) Start scraping centre detail for centre Ukrainian Co-Op Nursery School.
# 	Ward:	Etobicoke Centre
# 	Finish scraping. Sleep for a short moment.
# (1026) Start scraping centre detail for centre Unicorn Day Care Centre.
# 	Ward:	University-Rosedale
# 	Finish scraping. Sleep for a short moment.
# (1027) Start scraping centre detail for centre Unicorn Day Care Centre Toronto.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Avenue Rd./St. Clair
# 	Finish scraping. Sleep for a short moment.
# (1028) Start scraping centre detail for centre University City Jr YMCA.
# 	Ward:	Humber River-Black Creek
# 	Cross Street Reference:	Finch/Sentinel
# 	Finish scraping. Sleep for a short moment.
# (1029) Start scraping centre detail for centre University Of Toronto Childcare On Charles.
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Yonge/Charles
# 	Finish scraping. Sleep for a short moment.
# (1030) Start scraping centre detail for centre University Of Toronto Early Learning Centre - Glen Morris.
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	Spadina/Bloor
# 	Finish scraping. Sleep for a short moment.
# (1031) Start scraping centre detail for centre University Of Toronto Early Learning Centre - O.I.S.E..
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	Bloor/Bedford
# 	Finish scraping. Sleep for a short moment.
# (1032) Start scraping centre detail for centre University Settlement Day Care Centre.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Dundas/University
# 	Finish scraping. Sleep for a short moment.
# (1033) Start scraping centre detail for centre Uptown Montessori School.
# 	Ward:	York Centre
# 	Cross Street Reference:	Sheppard Ave W/Keele St
# 	Finish scraping. Sleep for a short moment.
# (1034) Start scraping centre detail for centre Uptown Yonge Preschool & Child Development Centre.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	York Mills/Yonge
# 	Finish scraping. Sleep for a short moment.
# (1035) Start scraping centre detail for centre Van Horne Day Care.
# 	Ward:	Don Valley North
# 	Cross Street Reference:	Don Mills/Van Horne
# 	Finish scraping. Sleep for a short moment.
# (1036) Start scraping centre detail for centre Vedic Roots Montessori Academy (Scarborough).
# 	Ward:	Scarborough-Guildwood
# 	Finish scraping. Sleep for a short moment.
# (1037) Start scraping centre detail for centre Victoria Education Centre, Montessori & Child Care.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Danforth Ave./Woodbine
# 	Finish scraping. Sleep for a short moment.
# (1038) Start scraping centre detail for centre Victoria Park Child Care Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Victoria Pk./Ellesmere
# 	Finish scraping. Sleep for a short moment.
# (1039) Start scraping centre detail for centre Village Green Child Care Centre.
# 	Ward:	Scarborough-Agincourt
# 	Cross Street Reference:	Kennedy Rd/Sheppard Ave. E.
# 	Finish scraping. Sleep for a short moment.
# (1040) Start scraping centre detail for centre Vincent Massey Academy - (521909 Ontario Ltd.).
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Lake Shore Blvd W/29th Street
# 	Finish scraping. Sleep for a short moment.
# (1041) Start scraping centre detail for centre Vincent Massey Childcare Center (521909 Ontario Ltd.).
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Browns Line/Horner
# 	Finish scraping. Sleep for a short moment.
# (1042) Start scraping centre detail for centre Viva Kids Academy.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Yonge St/York Mills Road
# 	Finish scraping. Sleep for a short moment.
# (1043) Start scraping centre detail for centre Vradenburg Community Child Care Centre.
# 	Ward:	Scarborough-Agincourt
# 	Finish scraping. Sleep for a short moment.
# (1044) Start scraping centre detail for centre Waldorf Academy Childcare Centre.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (1045) Start scraping centre detail for centre Waldorf Academy Childcare Centre-Madison.
# 	Ward:	Toronto-St. Paul's
# 	Finish scraping. Sleep for a short moment.
# (1046) Start scraping centre detail for centre Waterclub Jr YMCA.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	York/Queen's Quay
# 	Finish scraping. Sleep for a short moment.
# (1047) Start scraping centre detail for centre Waterfront Montessori Childrens Centre.
# 	Ward:	Spadina-Fort York
# 	Cross Street Reference:	Ward's Ferry/Algonquin Isl.
# 	Finish scraping. Sleep for a short moment.
# (1048) Start scraping centre detail for centre Waverley Road Montessori School.
# 	Ward:	Beaches-East York
# 	Finish scraping. Sleep for a short moment.
# (1049) Start scraping centre detail for centre Wedgewood School Age YMCA.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Burnhamthorpe/Kipling Ave.
# 	Finish scraping. Sleep for a short moment.
# (1050) Start scraping centre detail for centre Wee Leprechauns Child Care Centre Ltd.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	Lawrence/Don Mills
# 	Finish scraping. Sleep for a short moment.
# (1051) Start scraping centre detail for centre Wellesley Early Learning Centre - Earlscourt Creche CDI.
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Wellesley/Sherbourne
# 	Finish scraping. Sleep for a short moment.
# (1052) Start scraping centre detail for centre Wellesworth School Age YMCA.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Wellesworth/Renforth
# 	Finish scraping. Sleep for a short moment.
# (1053) Start scraping centre detail for centre West End Jr YMCA.
# 	Ward:	Davenport
# 	Cross Street Reference:	College/Dovercourt
# 	Finish scraping. Sleep for a short moment.
# (1054) Start scraping centre detail for centre West End Parents Day Care Centre.
# 	Ward:	Davenport
# 	Cross Street Reference:	Dovercourt/College
# 	Finish scraping. Sleep for a short moment.
# (1055) Start scraping centre detail for centre West End Parents Day Care Satellite.
# 	Ward:	Davenport
# 	Cross Street Reference:	College St./Ossington Ave.
# 	Finish scraping. Sleep for a short moment.
# (1056) Start scraping centre detail for centre West Hill Centre For Early Learning (Centres For Early Learning Inc.).
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Lawrence/Kingston Rd.
# 	Finish scraping. Sleep for a short moment.
# (1057) Start scraping centre detail for centre Westmount Junior School, Extended Day Program.
# 	Ward:	Etobicoke Centre
# 	Finish scraping. Sleep for a short moment.
# (1058) Start scraping centre detail for centre Weston Memorial B & A School Program.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Jane/Lawrence W.
# 	Finish scraping. Sleep for a short moment.
# (1059) Start scraping centre detail for centre Westown Early Learning And Child Care Centre.
# 	Ward:	Humber River-Black Creek
# 	Cross Street Reference:	Weston Rd./Sheppard
# 	Finish scraping. Sleep for a short moment.
# (1060) Start scraping centre detail for centre West Prep Children's Centre Of Toronto.
# 	Ward:	Eglinton-Lawrence
# 	Cross Street Reference:	Bathurst/Eglinton
# 	Finish scraping. Sleep for a short moment.
# (1061) Start scraping centre detail for centre West Rouge Kindergarten Extended Care Program.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	East Ave/Kirkdene Drive
# 	Finish scraping. Sleep for a short moment.
# (1062) Start scraping centre detail for centre Westside Montessori School.
# 	Ward:	University-Rosedale
# 	Finish scraping. Sleep for a short moment.
# (1063) Start scraping centre detail for centre Westside Montessori School.
# 	Ward:	Davenport
# 	Finish scraping. Sleep for a short moment.
# (1064) Start scraping centre detail for centre Wexford Community Childcare Centre.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Warden/Lawrence
# 	Finish scraping. Sleep for a short moment.
# (1065) Start scraping centre detail for centre Wexford Extended Day And School Age Program.
# 	Ward:	Scarborough Centre
# 	Cross Street Reference:	Victoria Park/Lawrence Ave E
# 	Finish scraping. Sleep for a short moment.
# (1066) Start scraping centre detail for centre Weybourne School.
# 	Ward:	Don Valley West
# 	Cross Street Reference:	Yonge St/Lawrence Ave E
# 	Finish scraping. Sleep for a short moment.
# (1067) Start scraping centre detail for centre Whitney Child Centre.
# 	Ward:	University-Rosedale
# 	Cross Street Reference:	Mount Pleasant/St. Clair
# 	Finish scraping. Sleep for a short moment.
# (1068) Start scraping centre detail for centre William Burgess Jr YMCA.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Pape/O'Connor
# 	Finish scraping. Sleep for a short moment.
# (1069) Start scraping centre detail for centre William G. Davis Kindergarten Extended Care Program.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	East Ave/Lawrence Ave
# 	Finish scraping. Sleep for a short moment.
# (1070) Start scraping centre detail for centre William G. Miller School Age YMCA.
# 	Ward:	Scarborough-Rouge Park
# 	Cross Street Reference:	Lawrence/Bennett
# 	Finish scraping. Sleep for a short moment.
# (1071) Start scraping centre detail for centre Williamson Road Day Care Centre.
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Queen/Lee
# 	Finish scraping. Sleep for a short moment.
# (1072) Start scraping centre detail for centre Willowbrae Academy Bayview Village.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Sheppard Ave E/Bayview Ave
# 	Finish scraping. Sleep for a short moment.
# (1073) Start scraping centre detail for centre Willowbrae Academy Etobicoke.
# 	Ward:	Etobicoke-Lakeshore
# 	Cross Street Reference:	Dundas St W/Cabot Ct
# 	Finish scraping. Sleep for a short moment.
# (1074) Start scraping centre detail for centre Willow Park Junior Public School, Extended Day Program.
# 	Ward:	Scarborough-Guildwood
# 	Cross Street Reference:	Lawrence Ave E/Scarb Golf Rd
# 	Finish scraping. Sleep for a short moment.
# (1075) Start scraping centre detail for centre Willowridge Early Learning & Child Care Centre.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Martingrove/Eglinton Ave. W.
# 	Finish scraping. Sleep for a short moment.
# (1076) Start scraping centre detail for centre Willow World.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Bayview Ave/Cummer Ave
# 	Finish scraping. Sleep for a short moment.
# (1077) Start scraping centre detail for centre Wilmington Best Child Care Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Finch/Wilmington
# 	Finish scraping. Sleep for a short moment.
# (1078) Start scraping centre detail for centre Wilmington Best Schoolage Satellite Centre.
# 	Ward:	York Centre
# 	Cross Street Reference:	Finch/Wilmington
# 	Finish scraping. Sleep for a short moment.
# (1079) Start scraping centre detail for centre Winchester Site Day Care (Central Neighbourhood House).
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Parliament/Wellesley
# 	Finish scraping. Sleep for a short moment.
# (1080) Start scraping centre detail for centre Windermere Early Learning Centre.
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	The Queensway/Windermere Ave
# 	Finish scraping. Sleep for a short moment.
# (1081) Start scraping centre detail for centre Windermere Kids Inc..
# 	Ward:	Parkdale-High Park
# 	Cross Street Reference:	Jane/Bloor
# 	Finish scraping. Sleep for a short moment.
# (1082) Start scraping centre detail for centre Withrow Child Care Centre.
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Broadview/Danforth
# 	Finish scraping. Sleep for a short moment.
# (1083) Start scraping centre detail for centre Wonderkids Daycare.
# 	Ward:	Etobicoke Centre
# 	Cross Street Reference:	Rathburn Rd/427
# 	Finish scraping. Sleep for a short moment.
# (1084) Start scraping centre detail for centre Woodgreen Community Services (Enderby Child Care).
# 	Ward:	Beaches-East York
# 	Cross Street Reference:	Main/Gerrard
# 	Finish scraping. Sleep for a short moment.
# (1085) Start scraping centre detail for centre Woodgreen Community Services (Leslieville Child Care).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Dundas/Leslie
# 	Finish scraping. Sleep for a short moment.
# (1086) Start scraping centre detail for centre Woodgreen Community Services (Morse Child Care Centre).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Queen/Carlaw
# 	Finish scraping. Sleep for a short moment.
# (1087) Start scraping centre detail for centre Woodgreen Community Services (Riverdale Child Care).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Gerrard/Leslie
# 	Finish scraping. Sleep for a short moment.
# (1088) Start scraping centre detail for centre Woodgreen Community Services (The)(Debbie Yeung Child Care Centre).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Donlands/Cosburn
# 	Finish scraping. Sleep for a short moment.
# (1089) Start scraping centre detail for centre Woodgreen Community Services (Woodfield Child Care Centre).
# 	Ward:	Toronto-Danforth
# 	Cross Street Reference:	Coxwell/Queen
# 	Finish scraping. Sleep for a short moment.
# (1090) Start scraping centre detail for centre Woodland Nursery School (Warden Woods Community Centre).
# 	Ward:	Scarborough Southwest
# 	Cross Street Reference:	Warden/St. Clair
# 	Finish scraping. Sleep for a short moment.
# (1091) Start scraping centre detail for centre Wychwood Tigers Daycare Centre.
# 	Ward:	Toronto-St. Paul's
# 	Cross Street Reference:	Eglinton Ave W/Bathurst St
# 	Finish scraping. Sleep for a short moment.
# (1092) Start scraping centre detail for centre Yeshivat Yesodei Hatora.
# 	Ward:	Eglinton-Lawrence
# 	Finish scraping. Sleep for a short moment.
# (1093) Start scraping centre detail for centre Yes I Can Nursery School.
# 	Ward:	Don Valley West
# 	Finish scraping. Sleep for a short moment.
# (1094) Start scraping centre detail for centre YMCA Child Development Centre (YMCA).
# 	Ward:	Toronto Centre
# 	Cross Street Reference:	Yonge/Wellesley
# 	Finish scraping. Sleep for a short moment.
# (1095) Start scraping centre detail for centre YMCA Of Greater Toronto - St Augustine.
# 	Ward:	Humber River-Black Creek
# 	Finish scraping. Sleep for a short moment.
# (1096) Start scraping centre detail for centre Yonge-Churchill Child Care Centre.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Yonge/Sheppard
# 	Finish scraping. Sleep for a short moment.
# (1097) Start scraping centre detail for centre Yonge Hearts Child Care Centre.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Yonge/Finch
# 	Finish scraping. Sleep for a short moment.
# (1098) Start scraping centre detail for centre York Heights Child Care Centre.
# 	Ward:	Temp. Pilot Data
# 	Cross Street Reference:	Dufferin/Hwy 401
# 	Finish scraping. Sleep for a short moment.
# (1099) Start scraping centre detail for centre York Humber Child Care.
# 	Ward:	York South-Weston
# 	Cross Street Reference:	Eglinton W./Jane
# 	Finish scraping. Sleep for a short moment.
# (1100) Start scraping centre detail for centre York Mills Child Care Centre.
# 	Ward:	Don Valley East
# 	Cross Street Reference:	York Mills/Dvp
# 	Finish scraping. Sleep for a short moment.
# (1101) Start scraping centre detail for centre Yorktown Montessori School.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Yonge/Finch
# 	Finish scraping. Sleep for a short moment.
# (1102) Start scraping centre detail for centre York University Co-Operative Day Care Centre.
# 	Ward:	Humber River-Black Creek
# 	Cross Street Reference:	Finch/Keele
# 	Finish scraping. Sleep for a short moment.
# (1103) Start scraping centre detail for centre Yorkview Kids Care - North York.
# 	Ward:	Willowdale
# 	Cross Street Reference:	Bathurst/Finch
# 	Finish scraping. Sleep for a short moment.
# (1104) Start scraping centre detail for centre Young Talents Academy.
# 	Ward:	Don Valley North
# 	Finish scraping. Sleep for a short moment.
# (1105) Start scraping centre detail for centre YWCA Bergamot Early Learning.
# 	Ward:	Etobicoke North
# 	Cross Street Reference:	Islington Ave./Rexdale Blvd.
# 	Finish scraping. Sleep for a short moment.

# %%
import pandas as pd

def main():
  df = pd.DataFrame(centres)
  print(df)

  # Export the DataFrame to a CSV file
  OUTPUT_FILE_NAME = 'toronto-az-child-care-centres.csv'
  OUTPUT_DESIRED_COLUMN_ORDER = ['name', 'address', 'cross_street_reference', 'ward', 'contact_name', 'phone', 'phone_extension', 'email', 'website']

  df.to_csv(OUTPUT_FILE_NAME, columns=OUTPUT_DESIRED_COLUMN_ORDER, index=False)
  print(f'DataFrame successfully exported to {OUTPUT_FILE_NAME}.')

# %%
if __name__ == '__main__':
  main()
# Out:
#                                                    name  \
# 0                                  A & A Daycare Centre
# 1                     Abacus Montessori Learning Centre
# 2     Abiona Centre For Infant And Early Mental Heal...
# 3     Abiona Centre For Infant And Early Mental Heal...
# 4                   Aboriginal Head Start - Epnigishmok
# ...                                                 ...
# 1101                         Yorktown Montessori School
# 1102       York University Co-Operative Day Care Centre
# 1103                    Yorkview Kids Care - North York
# 1104                              Young Talents Academy
# 1105                       YWCA Bergamot Early Learning
#
#                           ward        cross_street_reference  \
# 0        Scarborough-Agincourt              Midland/Finch E.
# 1            Beaches-East York                           NaN
# 2             Toronto-Danforth            Broadview/Mortimer
# 3           Toronto-St. Paul's            Christie/St. Clair
# 4           Toronto-St. Paul's                           NaN
# ...                        ...                           ...
# 1101                Willowdale                   Yonge/Finch
# 1102  Humber River-Black Creek                   Finch/Keele
# 1103                Willowdale                Bathurst/Finch
# 1104          Don Valley North                           NaN
# 1105           Etobicoke North  Islington Ave./Rexdale Blvd.
#
#                          address        contact_name         phone  \
# 0           3380 Midland Ave, 22     Angela McAloney  416-298-4489
# 1            2723 St Clair Ave E  Olive Somasunderam  416-285-8613
# 2             1102 Broadview Ave        Farwa Batool  437-328-2816
# 3                 40 Humewood Dr        Sue Sinclair  416-651-5657
# 4     20 Bansley Ave, Rm 119/120      Amanda Macewen  416-639-9036
# ...                          ...                 ...           ...
# 1101             349 Kenneth Ave          Grace Park  416-226-6932
# 1102      90 Atkinson Rd, Rm 128       Ayesha Ysraël  416-736-2100
# 1103             130 Yorkview Dr         Ruth Barber  416-221-7656
# 1104    2255 Sheppard Ave E, 100   Sayonara Siqueira  905-212-2215
# 1105             66 Bergamot Ave        Karen Hipson  416-748-8179
#
#      phone_extension email                 website
# 0                                              NaN
# 1                              abacusmontessori.ca
# 2                                              NaN
# 3                226                           NaN
# 4                                  nativechild.org
# ...              ...   ...                     ...
# 1101                                           NaN
# 1102           33273              yorku.ca/daycare
# 1103                                           NaN
# 1104                        youngtalentsacademy.ca
# 1105             310               ywcatoronto.org
#
# [1106 rows x 9 columns]
# DataFrame successfully exported to output.csv.
